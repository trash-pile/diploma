# %%
import cv2
import numpy as np
from dataclasses import dataclass
from time import time
from typing import Tuple, Optional
from pathlib import Path
import numba
from concurrent.futures import ThreadPoolExecutor
import os

@dataclass(frozen=True)
class Config:
    SCALE: float = 0.4
    NFEAT: int = 150000
    MATCH_RATIO: float = 0.65
    KEEP_PERCENT: float = 0.55
    THRESH: float = 250.0
    SIFT_EDGE_THRESHOLD: float = 10.0
    SIFT_CONTRAST_THRESHOLD: float = 0.04
    NUM_THREADS: int = os.cpu_count() if os.cpu_count() else 4
    SEARCH_FIELD_MULTIPLIER: float = 1.6  # Multiplier for search field size in each dimension
                                          # Results in (SEARCH_FIELD_MULTIPLIER^2)x larger search area
                                          # Also determines maximum canvas expansion when needed
                                          # Must be >= 1.0

class ImageStitcher:
    def __init__(self, path: str = "./folder2/"):
        self.path = Path(path)
        
        # Validate SEARCH_FIELD_MULTIPLIER
        if Config.SEARCH_FIELD_MULTIPLIER < 1.0:
            raise ValueError("SEARCH_FIELD_MULTIPLIER must be >= 1.0")
            
        self.sift = cv2.SIFT_create(
            nfeatures=Config.NFEAT,
            contrastThreshold=Config.SIFT_CONTRAST_THRESHOLD,
            edgeThreshold=Config.SIFT_EDGE_THRESHOLD
        )
        self.matcher = cv2.FlannBasedMatcher(
            dict(algorithm=1, trees=5),
            dict(checks=32)
        )
        self.last_match_region: Optional[Tuple[int, int]] = None
        self._gray_buffer1: Optional[np.ndarray] = None
        self._gray_buffer2: Optional[np.ndarray] = None
        self._base_image_size: Optional[Tuple[int, int]] = None  # Store base image size after scaling
        self._canvas_offset: Tuple[int, int] = (0, 0)  # Track cumulative offset from expansions
        print(f"Using {Config.NUM_THREADS} worker threads (all available cores)")
        print(f"Search field area multiplier: {Config.SEARCH_FIELD_MULTIPLIER}x each dimension "
              f"({Config.SEARCH_FIELD_MULTIPLIER**2:.2f}x total area)")
        self.thread_pool = ThreadPoolExecutor(max_workers=Config.NUM_THREADS)

    def read_image(self, idx: int) -> Tuple[np.ndarray, dict]:
        """
        Read and preprocess image, returning image and timing details.
        """
        timings = {}

        # Construct file path
        path_start = time()
        img_path = self.path / f"2023_09_01_SonyRX1RM2_g201b20538_f001_{idx:04}.JPG"
        timings['construct_path'] = time() - path_start

        # Read image from disk
        read_start = time()
        img = cv2.imread(str(img_path), cv2.IMREAD_COLOR)
        timings['read_from_disk'] = time() - read_start

        # Resize image
        resize_start = time()
        img = cv2.resize(img, None, fx=Config.SCALE, fy=Config.SCALE,
                        interpolation=cv2.INTER_AREA)
        timings['resize'] = time() - resize_start
        
        # Store base image size if not already set
        if self._base_image_size is None:
            self._base_image_size = (img.shape[1], img.shape[0])  # (width, height)
        
        # Convert to RGBA
        rgba_start = time()
        rgba = np.zeros((img.shape[0], img.shape[1], 4), dtype=np.uint8)
        rgba[:, :, :3] = img
        rgba[:, :, 3] = 255
        timings['convert_to_rgba'] = time() - rgba_start

        return rgba, timings

    def get_search_region_and_expand(self, img: np.ndarray) -> Tuple[np.ndarray, Tuple[int, int, int, int], Tuple[int, int]]:
        """
        Calculate search region and expand image if necessary.
        Returns expanded image, search region coordinates, and new offset.
        Expansion is based on SEARCH_FIELD_MULTIPLIER to ensure consistency.
        """
        h, w = img.shape[:2]
        
        if self.last_match_region is None:
            self.last_match_region = (w // 2, h // 2)  # Initialize to center
            return img, (0, 0, w, h), (0, 0)

        # Get base image dimensions after scaling
        base_w, base_h = self._base_image_size
        
        # Calculate desired search window dimensions
        search_w = int(round(base_w * Config.SEARCH_FIELD_MULTIPLIER**2))
        search_h = int(round(base_h * Config.SEARCH_FIELD_MULTIPLIER**2))
        search_w = max(base_w, search_w)  # Ensure search region is at least base size
        search_h = max(base_h, search_h)

        # Adjust last match region for current canvas offset
        cx, cy = self.last_match_region

        # Calculate desired search region (before boundary check)
        x1 = int(round(cx - search_w / 2))
        y1 = int(round(cy - search_h / 2))
        x2 = x1 + search_w
        y2 = y1 + search_h

        # Check if search region extends beyond image boundaries
        pad_left = max(0, -x1)
        pad_right = max(0, x2 - w)
        pad_top = max(0, -y1)
        pad_bottom = max(0, y2 - h)

        # Maximum allowed expansion based on SEARCH_FIELD_MULTIPLIER
        max_pad_w = int(round(base_w * Config.SEARCH_FIELD_MULTIPLIER**2))
        max_pad_h = int(round(base_h * Config.SEARCH_FIELD_MULTIPLIER**2))

        if pad_left or pad_right or pad_top or pad_bottom:
            # Limit padding to maximum allowed
            pad_left = min(pad_left, max_pad_w)
            pad_right = min(pad_right, max_pad_w)
            pad_top = min(pad_top, max_pad_h)
            pad_bottom = min(pad_bottom, max_pad_h)

            # Create new canvas with padding
            new_w = w + pad_left + pad_right
            new_h = h + pad_top + pad_bottom
            canvas = np.zeros((new_h, new_w, 4), dtype=np.uint8)
            canvas[pad_top:pad_top + h, pad_left:pad_left + w] = img
            
            # Update coordinates for new canvas
            x1 += pad_left
            x2 += pad_left
            y1 += pad_top
            y2 += pad_top
            
            result_img = canvas
            offset = (pad_left, pad_top)
            
            # Update canvas offset
            self._canvas_offset = (self._canvas_offset[0] + pad_left, 
                                 self._canvas_offset[1] + pad_top)
        else:
            result_img = img
            offset = (0, 0)

        # Clip search region to image boundaries
        x1 = max(0, x1)
        y1 = max(0, y1)
        x2 = min(result_img.shape[1], x2)
        y2 = min(result_img.shape[0], y2)

        return result_img, (x1, y1, x2, y2), offset

    def update_last_match_region(self, matrix: np.ndarray, img_shape: Tuple[int, int], 
                               offset: Tuple[int, int], crop_offset: Optional[Tuple[int, int]] = None):
        h, w = img_shape[:2]
        center = np.array([[w/2], [h/2], [1]], dtype=np.float32)
        transformed = matrix @ center
        
        # Adjust for expansion offset
        new_cx = int(transformed[0, 0]) + offset[0]
        new_cy = int(transformed[1, 0]) + offset[1]
        
        # Adjust for cropping if applicable
        if crop_offset:
            new_cx -= crop_offset[0]
            new_cy -= crop_offset[1]
            
        self.last_match_region = (new_cx, new_cy)

    def find_matches(self, img1: np.ndarray, img2: np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray, Tuple[int, int], dict]:
        """
        Find matches between images, returning results and timing details.
        """
        timings = {}

        # Expand search region (already timed separately in stitch)
        img1, (x1, y1, x2, y2), offset = self.get_search_region_and_expand(img1)
        
        # Verify that slice indices are valid
        if x2 <= x1 or y2 <= y1:
            raise ValueError(f"Invalid search region: x1={x1}, x2={x2}, y1={y1}, y2={y2}")
        
        # Extract ROI
        roi_start = time()
        img1_roi = img1[y1:y2, x1:x2]
        timings['extract_roi'] = time() - roi_start

        # Allocate grayscale buffers if needed
        buffer_start = time()
        if (self._gray_buffer1 is None or 
            self._gray_buffer1.shape != img1_roi.shape[:2]):
            self._gray_buffer1 = np.empty(img1_roi.shape[:2], dtype=np.uint8)
        if (self._gray_buffer2 is None or 
            self._gray_buffer2.shape != img2.shape[:2]):
            self._gray_buffer2 = np.empty(img2.shape[:2], dtype=np.uint8)
        timings['allocate_buffers'] = time() - buffer_start

        # Convert to grayscale in parallel
        gray_start = time()
        futures = [
            self.thread_pool.submit(cv2.cvtColor, img1_roi, cv2.COLOR_BGRA2GRAY, 
                                  dst=self._gray_buffer1),
            self.thread_pool.submit(cv2.cvtColor, img2, cv2.COLOR_BGRA2GRAY, 
                                  dst=self._gray_buffer2)
        ]
        for future in futures:
            future.result()
        timings['convert_to_grayscale'] = time() - gray_start

        # Detect SIFT features and descriptors in parallel
        def detect_compute(img, sift):
            return sift.detectAndCompute(img, None)
        
        sift_start = time()
        future_kp1 = self.thread_pool.submit(detect_compute, self._gray_buffer1, self.sift)
        future_kp2 = self.thread_pool.submit(detect_compute, self._gray_buffer2, self.sift)
        kp1, desc1 = future_kp1.result()
        kp2, desc2 = future_kp2.result()
        timings['sift_detection'] = time() - sift_start

        # Perform FLANN-based matching
        flann_start = time()
        matches = self.matcher.knnMatch(desc1, desc2, k=2)
        timings['flann_matching'] = time() - flann_start

        # Filter matches
        filter_start = time()
        good = [m for m, n in matches if m.distance < Config.MATCH_RATIO * n.distance]
        good = sorted(good, key=lambda x: x.distance)[:int(len(good) * Config.KEEP_PERCENT)]
        timings['filter_matches'] = time() - filter_start

        # Extract points
        points_start = time()
        query_idx = np.array([m.queryIdx for m in good])
        train_idx = np.array([m.trainIdx for m in good])
        pts1 = np.float32([kp.pt for kp in kp1])[query_idx] + [x1, y1]
        pts2 = np.float32([kp.pt for kp in kp2])[train_idx]
        timings['extract_points'] = time() - points_start

        return img1, pts1, pts2, offset, timings

    def align_images(self, pts1: np.ndarray, pts2: np.ndarray, 
                    img_shape: Tuple[int, int], offset: Tuple[int, int]) -> np.ndarray:
        matrix, _ = cv2.estimateAffinePartial2D(
            pts2, pts1,
            method=cv2.RANSAC,
            ransacReprojThreshold=Config.THRESH,
            confidence=0.995,
            maxIters=1000
        )
        return matrix

    @staticmethod
    @numba.jit(nopython=True, parallel=True)
    def overlay_images_numba(base: np.ndarray, overlay: np.ndarray, result: np.ndarray):
        h, w = base.shape[:2]
        for y in numba.prange(h):
            for x in range(w):
                if overlay[y, x, 3] > 0:
                    result[y, x] = overlay[y, x]
                else:
                    result[y, x] = base[y, x]

    def overlay_images(self, base: np.ndarray, overlay: np.ndarray) -> np.ndarray:
        result = np.zeros_like(base, dtype=np.uint8)
        ImageStitcher.overlay_images_numba(base, overlay, result)
        return result

    def crop_result(self, img: np.ndarray) -> Tuple[np.ndarray, Tuple[int, int]]:
        mask = img[:, :, 3] > 0
        rows = np.any(mask, axis=1)
        cols = np.any(mask, axis=0)
        y1, y2 = np.where(rows)[0][[0, -1]]
        x1, x2 = np.where(cols)[0][[0, -1]]
        crop_offset = (x1, y1)
        return img[y1:y2+1, x1:x2+1], crop_offset

    def stitch(self, start: int = 3, end: int = 100):
        print(f"\nStarting image stitching process from {start} to {end}")
        start_time = time()
        
        # Initialize with first image
        result_read_start = time()
        result, read_timings = self.read_image(start)
        result_read_time = time() - result_read_start
        
        total_images = end - start + 1  # Total number of images to process
        processed = 0

        # Process all images from start to end
        for idx in range(start, end + 1):
            iter_start = time()
            print(f"\nProcessing image {idx}/{end}")

            # Read image
            read_start = time()
            current, read_timings = self.read_image(idx)
            read_time = time() - read_start

            if idx == start:
                # For the first image, we need to initialize the result
                # and potentially expand it based on previous context
                expand_start = time()
                result, _, offset = self.get_search_region_and_expand(result)
                expand_time = time() - expand_start
                
                print(f"  - Read image: {read_time:.3f}s")
                print(f"    - Construct path: {read_timings['construct_path']:.3f}s")
                print(f"    - Read from disk: {read_timings['read_from_disk']:.3f}s")
                print(f"    - Resize: {read_timings['resize']:.3f}s")
                print(f"    - Convert to RGBA: {read_timings['convert_to_rgba']:.3f}s")
                print(f"  - Expand initial image: {expand_time:.3f}s")
                print(f"[Initial image, total {time() - iter_start:.3f}s]")
                processed += 1
                continue

            # Expand search region
            expand_start = time()
            result, _, offset = self.get_search_region_and_expand(result)
            expand_time = time() - expand_start

            # Find matches
            match_start = time()
            result, pts1, pts2, offset, match_timings = self.find_matches(result, current)
            match_time = time() - match_start

            # Align images
            align_start = time()
            matrix = self.align_images(pts1, pts2, current.shape, offset)
            align_time = time() - align_start

            # Warp and overlay
            warp_start = time()
            aligned = cv2.warpAffine(
                current, matrix,
                (result.shape[1], result.shape[0]),
                flags=cv2.INTER_LINEAR,
                borderMode=cv2.BORDER_TRANSPARENT
            )
            result = self.overlay_images(result, aligned)
            warp_time = time() - warp_start

            # Crop result
            crop_start = time()
            result, crop_offset = self.crop_result(result)
            crop_time = time() - crop_start

            # Update last match region
            update_start = time()
            self.update_last_match_region(matrix, current.shape, offset, crop_offset)
            update_time = time() - update_start

            # Print detailed timing
            print(f"  - Read image: {read_time:.3f}s")
            print(f"    - Construct path: {read_timings['construct_path']:.3f}s")
            print(f"    - Read from disk: {read_timings['read_from_disk']:.3f}s")
            print(f"    - Resize: {read_timings['resize']:.3f}s")
            print(f"    - Convert to RGBA: {read_timings['convert_to_rgba']:.3f}s")
            print(f"  - Expand search region: {expand_time:.3f}s")
            print(f"  - Find matches: {match_time:.3f}s")
            print(f"    - Extract ROI: {match_timings['extract_roi']:.3f}s")
            print(f"    - Allocate buffers: {match_timings['allocate_buffers']:.3f}s")
            print(f"    - Convert to grayscale: {match_timings['convert_to_grayscale']:.3f}s")
            print(f"    - SIFT detection: {match_timings['sift_detection']:.3f}s")
            print(f"    - FLANN matching: {match_timings['flann_matching']:.3f}s")
            print(f"    - Filter matches: {match_timings['filter_matches']:.3f}s")
            print(f"    - Extract points: {match_timings['extract_points']:.3f}s")
            print(f"  - Align images: {align_time:.3f}s")
            print(f"  - Warp and overlay: {warp_time:.3f}s")
            print(f"  - Crop result: {crop_time:.3f}s")
            print(f"  - Update match region: {update_time:.3f}s")
            print(f"[Total for image {idx}: {time() - iter_start:.3f}s]")

            if idx % 10 == 0:
                cv2.imwrite(f"result_{idx}.png", result)
                print(f"  - Saved result_{idx}.png")

            processed += 1

        total_time = time() - start_time
        print(f"\nStitching completed:")
        print(f"Total images processed: {processed}/{total_images}")
        print(f"Total time: {total_time:.3f}s "
              f"(avg {total_time/total_images:.3f}s per image)")

    def __del__(self):
        self.thread_pool.shutdown()

if __name__ == "__main__":
    stitcher = ImageStitcher()
    stitcher.stitch()
# Out:
# Using 16 worker threads (all available cores)
# Search field area multiplier: 1.6x each dimension (2.56x total area)
#
# Starting image stitching process from 3 to 100
#
# Processing image 3/100
#   - Read image: 0.317s
#     - Construct path: 0.000s
#     - Read from disk: 0.260s
#     - Resize: 0.023s
#     - Convert to RGBA: 0.033s
#   - Expand initial image: 0.000s
# [Initial image, total 0.317s]
#
# Processing image 4/100
#   - Read image: 0.305s
#     - Construct path: 0.000s
#     - Read from disk: 0.246s
#     - Resize: 0.025s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.011s
#   - Find matches: 13.665s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.014s
#     - SIFT detection: 7.846s
#     - FLANN matching: 5.532s
#     - Filter matches: 0.021s
#     - Extract points: 0.148s
#   - Align images: 0.001s
#   - Warp and overlay: 0.706s
#   - Crop result: 0.073s
#   - Update match region: 0.000s
# [Total for image 4: 14.761s]
#
# Processing image 5/100
#   - Read image: 0.307s
#     - Construct path: 0.000s
#     - Read from disk: 0.251s
#     - Resize: 0.023s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.022s
#   - Find matches: 13.531s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 7.857s
#     - FLANN matching: 5.488s
#     - Filter matches: 0.020s
#     - Extract points: 0.144s
#   - Align images: 0.001s
#   - Warp and overlay: 0.131s
#   - Crop result: 0.039s
#   - Update match region: 0.001s
# [Total for image 5: 14.033s]
#
# Processing image 6/100
#   - Read image: 0.312s
#     - Construct path: 0.000s
#     - Read from disk: 0.253s
#     - Resize: 0.026s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.020s
#   - Find matches: 10.476s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 7.506s
#     - FLANN matching: 2.776s
#     - Filter matches: 0.006s
#     - Extract points: 0.082s
#   - Align images: 0.000s
#   - Warp and overlay: 0.184s
#   - Crop result: 0.062s
#   - Update match region: 0.000s
# [Total for image 6: 11.054s]
#
# Processing image 7/100
#   - Read image: 0.308s
#     - Construct path: 0.000s
#     - Read from disk: 0.252s
#     - Resize: 0.023s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.031s
#   - Find matches: 13.716s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 7.873s
#     - FLANN matching: 5.594s
#     - Filter matches: 0.020s
#     - Extract points: 0.135s
#   - Align images: 0.000s
#   - Warp and overlay: 0.111s
#   - Crop result: 0.046s
#   - Update match region: 0.000s
# [Total for image 7: 14.212s]
#
# Processing image 8/100
#   - Read image: 0.306s
#     - Construct path: 0.000s
#     - Read from disk: 0.249s
#     - Resize: 0.025s
#     - Convert to RGBA: 0.031s
#   - Expand search region: 0.029s
#   - Find matches: 11.764s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 7.621s
#     - FLANN matching: 3.908s
#     - Filter matches: 0.013s
#     - Extract points: 0.108s
#   - Align images: 0.000s
#   - Warp and overlay: 0.172s
#   - Crop result: 0.068s
#   - Update match region: 0.000s
# [Total for image 8: 12.339s]
#
# Processing image 9/100
#   - Read image: 0.334s
#     - Construct path: 0.000s
#     - Read from disk: 0.272s
#     - Resize: 0.027s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.044s
#   - Find matches: 13.890s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 8.019s
#     - FLANN matching: 5.619s
#     - Filter matches: 0.020s
#     - Extract points: 0.141s
#   - Align images: 0.000s
#   - Warp and overlay: 0.109s
#   - Crop result: 0.043s
#   - Update match region: 0.000s
# [Total for image 9: 14.422s]
#
# Processing image 10/100
#   - Read image: 0.306s
#     - Construct path: 0.000s
#     - Read from disk: 0.249s
#     - Resize: 0.024s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.036s
#   - Find matches: 11.949s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.009s
#     - SIFT detection: 7.470s
#     - FLANN matching: 4.246s
#     - Filter matches: 0.015s
#     - Extract points: 0.116s
#   - Align images: 0.000s
#   - Warp and overlay: 0.173s
#   - Crop result: 0.073s
#   - Update match region: 0.000s
# [Total for image 10: 12.537s]
#   - Saved result_10.png
#
# Processing image 11/100
#   - Read image: 0.307s
#     - Construct path: 0.000s
#     - Read from disk: 0.248s
#     - Resize: 0.025s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.046s
#   - Find matches: 14.430s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 8.067s
#     - FLANN matching: 6.115s
#     - Filter matches: 0.019s
#     - Extract points: 0.142s
#   - Align images: 0.000s
#   - Warp and overlay: 0.126s
#   - Crop result: 0.067s
#   - Update match region: 0.000s
# [Total for image 11: 14.976s]
#
# Processing image 12/100
#   - Read image: 0.311s
#     - Construct path: 0.000s
#     - Read from disk: 0.253s
#     - Resize: 0.024s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.044s
#   - Find matches: 12.015s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 8.435s
#     - FLANN matching: 3.369s
#     - Filter matches: 0.008s
#     - Extract points: 0.098s
#   - Align images: 0.000s
#   - Warp and overlay: 0.187s
#   - Crop result: 0.082s
#   - Update match region: 0.000s
# [Total for image 12: 12.639s]
#
# Processing image 13/100
#   - Read image: 0.300s
#     - Construct path: 0.001s
#     - Read from disk: 0.244s
#     - Resize: 0.022s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.077s
#   - Find matches: 14.371s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 8.441s
#     - FLANN matching: 5.657s
#     - Filter matches: 0.019s
#     - Extract points: 0.139s
#   - Align images: 0.000s
#   - Warp and overlay: 0.172s
#   - Crop result: 0.061s
#   - Update match region: 0.000s
# [Total for image 13: 14.981s]
#
# Processing image 14/100
#   - Read image: 0.310s
#     - Construct path: 0.000s
#     - Read from disk: 0.254s
#     - Resize: 0.022s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.070s
#   - Find matches: 12.429s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 7.914s
#     - FLANN matching: 4.248s
#     - Filter matches: 0.012s
#     - Extract points: 0.109s
#   - Align images: 0.000s
#   - Warp and overlay: 0.210s
#   - Crop result: 0.092s
#   - Update match region: 0.000s
# [Total for image 14: 13.111s]
#
# Processing image 15/100
#   - Read image: 0.334s
#     - Construct path: 0.000s
#     - Read from disk: 0.275s
#     - Resize: 0.022s
#     - Convert to RGBA: 0.035s
#   - Expand search region: 0.066s
#   - Find matches: 13.650s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 7.757s
#     - FLANN matching: 5.624s
#     - Filter matches: 0.019s
#     - Extract points: 0.137s
#   - Align images: 0.000s
#   - Warp and overlay: 0.162s
#   - Crop result: 0.092s
#   - Update match region: 0.000s
# [Total for image 15: 14.304s]
#
# Processing image 16/100
#   - Read image: 0.306s
#     - Construct path: 0.000s
#     - Read from disk: 0.250s
#     - Resize: 0.023s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.060s
#   - Find matches: 12.872s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.009s
#     - SIFT detection: 7.263s
#     - FLANN matching: 5.321s
#     - Filter matches: 0.021s
#     - Extract points: 0.139s
#   - Align images: 0.001s
#   - Warp and overlay: 0.195s
#   - Crop result: 0.085s
#   - Update match region: 0.000s
# [Total for image 16: 13.519s]
#
# Processing image 17/100
#   - Read image: 0.310s
#     - Construct path: 0.000s
#     - Read from disk: 0.252s
#     - Resize: 0.023s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.061s
#   - Find matches: 13.851s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 8.138s
#     - FLANN matching: 5.390s
#     - Filter matches: 0.019s
#     - Extract points: 0.138s
#   - Align images: 0.000s
#   - Warp and overlay: 0.180s
#   - Crop result: 0.098s
#   - Update match region: 0.000s
# [Total for image 17: 14.500s]
#
# Processing image 18/100
#   - Read image: 0.304s
#     - Construct path: 0.000s
#     - Read from disk: 0.249s
#     - Resize: 0.022s
#     - Convert to RGBA: 0.031s
#   - Expand search region: 0.062s
#   - Find matches: 12.952s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 7.350s
#     - FLANN matching: 5.328s
#     - Filter matches: 0.020s
#     - Extract points: 0.139s
#   - Align images: 0.001s
#   - Warp and overlay: 0.166s
#   - Crop result: 0.071s
#   - Update match region: 0.000s
# [Total for image 18: 13.556s]
#
# Processing image 19/100
#   - Read image: 0.313s
#     - Construct path: 0.000s
#     - Read from disk: 0.256s
#     - Resize: 0.024s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.079s
#   - Find matches: 13.314s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 7.737s
#     - FLANN matching: 5.266s
#     - Filter matches: 0.020s
#     - Extract points: 0.138s
#   - Align images: 0.000s
#   - Warp and overlay: 0.180s
#   - Crop result: 0.073s
#   - Update match region: 0.000s
# [Total for image 19: 13.961s]
#
# Processing image 20/100
#   - Read image: 0.312s
#     - Construct path: 0.000s
#     - Read from disk: 0.258s
#     - Resize: 0.021s
#     - Convert to RGBA: 0.031s
#   - Expand search region: 0.061s
#   - Find matches: 13.628s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 8.169s
#     - FLANN matching: 5.164s
#     - Filter matches: 0.020s
#     - Extract points: 0.134s
#   - Align images: 0.000s
#   - Warp and overlay: 0.169s
#   - Crop result: 0.069s
#   - Update match region: 0.000s
# [Total for image 20: 14.240s]
#   - Saved result_20.png
#
# Processing image 21/100
#   - Read image: 0.308s
#     - Construct path: 0.000s
#     - Read from disk: 0.251s
#     - Resize: 0.023s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.064s
#   - Find matches: 14.469s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.009s
#     - SIFT detection: 8.452s
#     - FLANN matching: 5.711s
#     - Filter matches: 0.020s
#     - Extract points: 0.140s
#   - Align images: 0.001s
#   - Warp and overlay: 0.213s
#   - Crop result: 0.091s
#   - Update match region: 0.000s
# [Total for image 21: 15.148s]
#
# Processing image 22/100
#   - Read image: 0.315s
#     - Construct path: 0.000s
#     - Read from disk: 0.258s
#     - Resize: 0.022s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.062s
#   - Find matches: 13.983s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 8.406s
#     - FLANN matching: 5.310s
#     - Filter matches: 0.020s
#     - Extract points: 0.136s
#   - Align images: 0.001s
#   - Warp and overlay: 0.162s
#   - Crop result: 0.068s
#   - Update match region: 0.000s
# [Total for image 22: 14.591s]
#
# Processing image 23/100
#   - Read image: 0.300s
#     - Construct path: 0.000s
#     - Read from disk: 0.246s
#     - Resize: 0.021s
#     - Convert to RGBA: 0.031s
#   - Expand search region: 0.062s
#   - Find matches: 13.790s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.009s
#     - SIFT detection: 8.197s
#     - FLANN matching: 5.258s
#     - Filter matches: 0.020s
#     - Extract points: 0.134s
#   - Align images: 0.001s
#   - Warp and overlay: 0.186s
#   - Crop result: 0.088s
#   - Update match region: 0.000s
# [Total for image 23: 14.427s]
#
# Processing image 24/100
#   - Read image: 0.301s
#     - Construct path: 0.000s
#     - Read from disk: 0.246s
#     - Resize: 0.021s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.064s
#   - Find matches: 13.832s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 8.247s
#     - FLANN matching: 5.321s
#     - Filter matches: 0.020s
#     - Extract points: 0.136s
#   - Align images: 0.000s
#   - Warp and overlay: 0.162s
#   - Crop result: 0.067s
#   - Update match region: 0.000s
# [Total for image 24: 14.426s]
#
# Processing image 25/100
#   - Read image: 0.299s
#     - Construct path: 0.000s
#     - Read from disk: 0.245s
#     - Resize: 0.021s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.063s
#   - Find matches: 13.762s
#     - Extract ROI: 0.001s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 8.094s
#     - FLANN matching: 5.352s
#     - Filter matches: 0.021s
#     - Extract points: 0.136s
#   - Align images: 0.001s
#   - Warp and overlay: 0.202s
#   - Crop result: 0.080s
#   - Update match region: 0.000s
# [Total for image 25: 14.407s]
#
# Processing image 26/100
#   - Read image: 0.307s
#     - Construct path: 0.000s
#     - Read from disk: 0.252s
#     - Resize: 0.021s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.065s
#   - Find matches: 13.645s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 8.051s
#     - FLANN matching: 5.314s
#     - Filter matches: 0.020s
#     - Extract points: 0.136s
#   - Align images: 0.000s
#   - Warp and overlay: 0.185s
#   - Crop result: 0.094s
#   - Update match region: 0.000s
# [Total for image 26: 14.296s]
#
# Processing image 27/100
#   - Read image: 0.322s
#     - Construct path: 0.000s
#     - Read from disk: 0.267s
#     - Resize: 0.022s
#     - Convert to RGBA: 0.031s
#   - Expand search region: 0.068s
#   - Find matches: 13.383s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 7.685s
#     - FLANN matching: 5.368s
#     - Filter matches: 0.019s
#     - Extract points: 0.134s
#   - Align images: 0.001s
#   - Warp and overlay: 0.262s
#   - Crop result: 0.091s
#   - Update match region: 0.000s
# [Total for image 27: 14.128s]
#
# Processing image 28/100
#   - Read image: 0.327s
#     - Construct path: 0.000s
#     - Read from disk: 0.270s
#     - Resize: 0.022s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.078s
#   - Find matches: 13.185s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 7.721s
#     - FLANN matching: 5.169s
#     - Filter matches: 0.020s
#     - Extract points: 0.137s
#   - Align images: 0.001s
#   - Warp and overlay: 0.216s
#   - Crop result: 0.099s
#   - Update match region: 0.000s
# [Total for image 28: 13.906s]
#
# Processing image 29/100
#   - Read image: 0.296s
#     - Construct path: 0.000s
#     - Read from disk: 0.239s
#     - Resize: 0.023s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.080s
#   - Find matches: 13.313s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 7.679s
#     - FLANN matching: 5.295s
#     - Filter matches: 0.020s
#     - Extract points: 0.141s
#   - Align images: 0.000s
#   - Warp and overlay: 0.273s
#   - Crop result: 0.097s
#   - Update match region: 0.000s
# [Total for image 29: 14.059s]
#
# Processing image 30/100
#   - Read image: 0.299s
#     - Construct path: 0.000s
#     - Read from disk: 0.244s
#     - Resize: 0.021s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.091s
#   - Find matches: 13.681s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 7.946s
#     - FLANN matching: 5.445s
#     - Filter matches: 0.019s
#     - Extract points: 0.136s
#   - Align images: 0.000s
#   - Warp and overlay: 0.217s
#   - Crop result: 0.092s
#   - Update match region: 0.000s
# [Total for image 30: 14.380s]
#   - Saved result_30.png
#
# Processing image 31/100
#   - Read image: 0.320s
#     - Construct path: 0.000s
#     - Read from disk: 0.264s
#     - Resize: 0.021s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.096s
#   - Find matches: 14.676s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.009s
#     - SIFT detection: 8.340s
#     - FLANN matching: 5.994s
#     - Filter matches: 0.019s
#     - Extract points: 0.137s
#   - Align images: 0.000s
#   - Warp and overlay: 0.301s
#   - Crop result: 0.104s
#   - Update match region: 0.000s
# [Total for image 31: 15.497s]
#
# Processing image 32/100
#   - Read image: 0.353s
#     - Construct path: 0.000s
#     - Read from disk: 0.294s
#     - Resize: 0.021s
#     - Convert to RGBA: 0.037s
#   - Expand search region: 0.094s
#   - Find matches: 14.942s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 9.259s
#     - FLANN matching: 5.401s
#     - Filter matches: 0.020s
#     - Extract points: 0.136s
#   - Align images: 0.000s
#   - Warp and overlay: 0.219s
#   - Crop result: 0.095s
#   - Update match region: 0.000s
# [Total for image 32: 15.703s]
#
# Processing image 33/100
#   - Read image: 0.320s
#     - Construct path: 0.000s
#     - Read from disk: 0.263s
#     - Resize: 0.023s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.116s
#   - Find matches: 14.528s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 8.500s
#     - FLANN matching: 5.618s
#     - Filter matches: 0.021s
#     - Extract points: 0.151s
#   - Align images: 0.007s
#   - Warp and overlay: 0.296s
#   - Crop result: 0.115s
#   - Update match region: 0.006s
# [Total for image 33: 15.389s]
#
# Processing image 34/100
#   - Read image: 0.326s
#     - Construct path: 0.000s
#     - Read from disk: 0.265s
#     - Resize: 0.027s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.082s
#   - Find matches: 14.111s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.014s
#     - SIFT detection: 8.489s
#     - FLANN matching: 5.346s
#     - Filter matches: 0.020s
#     - Extract points: 0.134s
#   - Align images: 0.001s
#   - Warp and overlay: 0.252s
#   - Crop result: 0.099s
#   - Update match region: 0.000s
# [Total for image 34: 14.872s]
#
# Processing image 35/100
#   - Read image: 0.337s
#     - Construct path: 0.000s
#     - Read from disk: 0.277s
#     - Resize: 0.024s
#     - Convert to RGBA: 0.034s
#   - Expand search region: 0.128s
#   - Find matches: 13.845s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 7.824s
#     - FLANN matching: 5.641s
#     - Filter matches: 0.021s
#     - Extract points: 0.141s
#   - Align images: 0.000s
#   - Warp and overlay: 0.330s
#   - Crop result: 0.131s
#   - Update match region: 0.000s
# [Total for image 35: 14.771s]
#
# Processing image 36/100
#   - Read image: 0.317s
#     - Construct path: 0.000s
#     - Read from disk: 0.260s
#     - Resize: 0.024s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.089s
#   - Find matches: 13.792s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 8.127s
#     - FLANN matching: 5.326s
#     - Filter matches: 0.020s
#     - Extract points: 0.136s
#   - Align images: 0.001s
#   - Warp and overlay: 0.281s
#   - Crop result: 0.141s
#   - Update match region: 0.000s
# [Total for image 36: 14.621s]
#
# Processing image 37/100
#   - Read image: 0.319s
#     - Construct path: 0.000s
#     - Read from disk: 0.263s
#     - Resize: 0.023s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.135s
#   - Find matches: 13.560s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.009s
#     - SIFT detection: 7.666s
#     - FLANN matching: 5.501s
#     - Filter matches: 0.020s
#     - Extract points: 0.132s
#   - Align images: 0.000s
#   - Warp and overlay: 0.364s
#   - Crop result: 0.143s
#   - Update match region: 0.000s
# [Total for image 37: 14.521s]
#
# Processing image 38/100
#   - Read image: 0.331s
#     - Construct path: 0.000s
#     - Read from disk: 0.263s
#     - Resize: 0.027s
#     - Convert to RGBA: 0.039s
#   - Expand search region: 0.131s
#   - Find matches: 14.027s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 8.666s
#     - FLANN matching: 5.069s
#     - Filter matches: 0.020s
#     - Extract points: 0.127s
#   - Align images: 0.000s
#   - Warp and overlay: 0.306s
#   - Crop result: 0.133s
#   - Update match region: 0.000s
# [Total for image 38: 14.928s]
#
# Processing image 39/100
#   - Read image: 0.316s
#     - Construct path: 0.000s
#     - Read from disk: 0.257s
#     - Resize: 0.025s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.208s
#   - Find matches: 13.645s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 7.937s
#     - FLANN matching: 5.295s
#     - Filter matches: 0.020s
#     - Extract points: 0.134s
#   - Align images: 0.000s
#   - Warp and overlay: 0.424s
#   - Crop result: 0.174s
#   - Update match region: 0.000s
# [Total for image 39: 14.768s]
#
# Processing image 40/100
#   - Read image: 0.314s
#     - Construct path: 0.000s
#     - Read from disk: 0.259s
#     - Resize: 0.021s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.114s
#   - Find matches: 13.627s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.009s
#     - SIFT detection: 7.777s
#     - FLANN matching: 5.528s
#     - Filter matches: 0.020s
#     - Extract points: 0.143s
#   - Align images: 0.000s
#   - Warp and overlay: 0.351s
#   - Crop result: 0.147s
#   - Update match region: 0.000s
# [Total for image 40: 14.553s]
#   - Saved result_40.png
#
# Processing image 41/100
#   - Read image: 0.312s
#     - Construct path: 0.000s
#     - Read from disk: 0.255s
#     - Resize: 0.022s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.179s
#   - Find matches: 16.218s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 9.709s
#     - FLANN matching: 6.052s
#     - Filter matches: 0.022s
#     - Extract points: 0.153s
#   - Align images: 0.009s
#   - Warp and overlay: 0.476s
#   - Crop result: 0.201s
#   - Update match region: 0.006s
# [Total for image 41: 17.401s]
#
# Processing image 42/100
#   - Read image: 0.316s
#     - Construct path: 0.000s
#     - Read from disk: 0.259s
#     - Resize: 0.023s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.131s
#   - Find matches: 16.138s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.014s
#     - SIFT detection: 9.673s
#     - FLANN matching: 6.096s
#     - Filter matches: 0.022s
#     - Extract points: 0.156s
#   - Align images: 0.010s
#   - Warp and overlay: 0.490s
#   - Crop result: 0.176s
#   - Update match region: 0.006s
# [Total for image 42: 17.267s]
#
# Processing image 43/100
#   - Read image: 0.337s
#     - Construct path: 0.000s
#     - Read from disk: 0.274s
#     - Resize: 0.028s
#     - Convert to RGBA: 0.034s
#   - Expand search region: 0.247s
#   - Find matches: 15.531s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.017s
#     - SIFT detection: 9.285s
#     - FLANN matching: 5.739s
#     - Filter matches: 0.023s
#     - Extract points: 0.152s
#   - Align images: 0.010s
#   - Warp and overlay: 0.573s
#   - Crop result: 0.201s
#   - Update match region: 0.000s
# [Total for image 43: 16.902s]
#
# Processing image 44/100
#   - Read image: 0.324s
#     - Construct path: 0.000s
#     - Read from disk: 0.264s
#     - Resize: 0.026s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.150s
#   - Find matches: 15.776s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.012s
#     - SIFT detection: 9.394s
#     - FLANN matching: 5.945s
#     - Filter matches: 0.022s
#     - Extract points: 0.155s
#   - Align images: 0.010s
#   - Warp and overlay: 0.457s
#   - Crop result: 0.203s
#   - Update match region: 0.006s
# [Total for image 44: 16.929s]
#
# Processing image 45/100
#   - Read image: 0.329s
#     - Construct path: 0.001s
#     - Read from disk: 0.266s
#     - Resize: 0.028s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.213s
#   - Find matches: 14.175s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.064s
#     - SIFT detection: 8.147s
#     - FLANN matching: 5.455s
#     - Filter matches: 0.020s
#     - Extract points: 0.144s
#   - Align images: 0.000s
#   - Warp and overlay: 0.528s
#   - Crop result: 0.199s
#   - Update match region: 0.000s
# [Total for image 45: 15.445s]
#
# Processing image 46/100
#   - Read image: 0.337s
#     - Construct path: 0.000s
#     - Read from disk: 0.277s
#     - Resize: 0.024s
#     - Convert to RGBA: 0.035s
#   - Expand search region: 0.180s
#   - Find matches: 13.701s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 7.952s
#     - FLANN matching: 5.355s
#     - Filter matches: 0.021s
#     - Extract points: 0.139s
#   - Align images: 0.000s
#   - Warp and overlay: 0.471s
#   - Crop result: 0.240s
#   - Update match region: 0.000s
# [Total for image 46: 14.929s]
#
# Processing image 47/100
#   - Read image: 0.325s
#     - Construct path: 0.000s
#     - Read from disk: 0.267s
#     - Resize: 0.024s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.227s
#   - Find matches: 14.220s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 8.379s
#     - FLANN matching: 5.332s
#     - Filter matches: 0.020s
#     - Extract points: 0.135s
#   - Align images: 0.001s
#   - Warp and overlay: 0.598s
#   - Crop result: 0.241s
#   - Update match region: 0.000s
# [Total for image 47: 15.613s]
#
# Processing image 48/100
#   - Read image: 0.315s
#     - Construct path: 0.000s
#     - Read from disk: 0.256s
#     - Resize: 0.025s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.181s
#   - Find matches: 14.247s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 8.164s
#     - FLANN matching: 5.649s
#     - Filter matches: 0.020s
#     - Extract points: 0.135s
#   - Align images: 0.010s
#   - Warp and overlay: 0.563s
#   - Crop result: 0.216s
#   - Update match region: 0.001s
# [Total for image 48: 15.533s]
#
# Processing image 49/100
#   - Read image: 0.319s
#     - Construct path: 0.000s
#     - Read from disk: 0.263s
#     - Resize: 0.023s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.251s
#   - Find matches: 13.772s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 8.018s
#     - FLANN matching: 5.211s
#     - Filter matches: 0.021s
#     - Extract points: 0.137s
#   - Align images: 0.001s
#   - Warp and overlay: 0.621s
#   - Crop result: 0.280s
#   - Update match region: 0.000s
# [Total for image 49: 15.245s]
#
# Processing image 50/100
#   - Read image: 0.314s
#     - Construct path: 0.000s
#     - Read from disk: 0.256s
#     - Resize: 0.025s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.198s
#   - Find matches: 13.798s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 8.277s
#     - FLANN matching: 5.105s
#     - Filter matches: 0.020s
#     - Extract points: 0.127s
#   - Align images: 0.001s
#   - Warp and overlay: 0.566s
#   - Crop result: 0.245s
#   - Update match region: 0.000s
# [Total for image 50: 15.124s]
#   - Saved result_50.png
#
# Processing image 51/100
#   - Read image: 0.300s
#     - Construct path: 0.000s
#     - Read from disk: 0.242s
#     - Resize: 0.024s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.270s
#   - Find matches: 14.236s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.001s
#     - Convert to grayscale: 0.009s
#     - SIFT detection: 8.529s
#     - FLANN matching: 5.114s
#     - Filter matches: 0.020s
#     - Extract points: 0.139s
#   - Align images: 0.011s
#   - Warp and overlay: 0.711s
#   - Crop result: 0.263s
#   - Update match region: 0.005s
# [Total for image 51: 15.797s]
#
# Processing image 52/100
#   - Read image: 0.327s
#     - Construct path: 0.000s
#     - Read from disk: 0.269s
#     - Resize: 0.024s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.211s
#   - Find matches: 13.502s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.014s
#     - SIFT detection: 8.054s
#     - FLANN matching: 5.010s
#     - Filter matches: 0.021s
#     - Extract points: 0.133s
#   - Align images: 0.010s
#   - Warp and overlay: 0.628s
#   - Crop result: 0.227s
#   - Update match region: 0.005s
# [Total for image 52: 14.911s]
#
# Processing image 53/100
#   - Read image: 0.355s
#     - Construct path: 0.000s
#     - Read from disk: 0.294s
#     - Resize: 0.026s
#     - Convert to RGBA: 0.034s
#   - Expand search region: 0.290s
#   - Find matches: 14.005s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.015s
#     - SIFT detection: 8.424s
#     - FLANN matching: 4.979s
#     - Filter matches: 0.023s
#     - Extract points: 0.136s
#   - Align images: 0.009s
#   - Warp and overlay: 0.741s
#   - Crop result: 0.295s
#   - Update match region: 0.008s
# [Total for image 53: 15.706s]
#
# Processing image 54/100
#   - Read image: 0.323s
#     - Construct path: 0.001s
#     - Read from disk: 0.260s
#     - Resize: 0.027s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.224s
#   - Find matches: 15.577s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.015s
#     - SIFT detection: 10.080s
#     - FLANN matching: 4.983s
#     - Filter matches: 0.021s
#     - Extract points: 0.145s
#   - Align images: 0.011s
#   - Warp and overlay: 0.681s
#   - Crop result: 0.273s
#   - Update match region: 0.006s
# [Total for image 54: 17.096s]
#
# Processing image 55/100
#   - Read image: 0.318s
#     - Construct path: 0.001s
#     - Read from disk: 0.256s
#     - Resize: 0.027s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.324s
#   - Find matches: 15.034s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.016s
#     - SIFT detection: 9.315s
#     - FLANN matching: 5.095s
#     - Filter matches: 0.023s
#     - Extract points: 0.134s
#   - Align images: 0.000s
#   - Warp and overlay: 0.738s
#   - Crop result: 0.347s
#   - Update match region: 0.001s
# [Total for image 55: 16.763s]
#
# Processing image 56/100
#   - Read image: 0.309s
#     - Construct path: 0.001s
#     - Read from disk: 0.250s
#     - Resize: 0.025s
#     - Convert to RGBA: 0.031s
#   - Expand search region: 0.236s
#   - Find matches: 13.676s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.013s
#     - SIFT detection: 8.080s
#     - FLANN matching: 5.089s
#     - Filter matches: 0.020s
#     - Extract points: 0.126s
#   - Align images: 0.000s
#   - Warp and overlay: 0.698s
#   - Crop result: 0.293s
#   - Update match region: 0.000s
# [Total for image 56: 15.212s]
#
# Processing image 57/100
#   - Read image: 0.318s
#     - Construct path: 0.000s
#     - Read from disk: 0.257s
#     - Resize: 0.027s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.341s
#   - Find matches: 15.287s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 9.562s
#     - FLANN matching: 5.114s
#     - Filter matches: 0.020s
#     - Extract points: 0.130s
#   - Align images: 0.000s
#   - Warp and overlay: 0.898s
#   - Crop result: 0.317s
#   - Update match region: 0.001s
# [Total for image 57: 17.163s]
#
# Processing image 58/100
#   - Read image: 0.314s
#     - Construct path: 0.000s
#     - Read from disk: 0.255s
#     - Resize: 0.024s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.274s
#   - Find matches: 15.380s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.051s
#     - SIFT detection: 9.599s
#     - FLANN matching: 5.219s
#     - Filter matches: 0.021s
#     - Extract points: 0.146s
#   - Align images: 0.010s
#   - Warp and overlay: 0.735s
#   - Crop result: 0.296s
#   - Update match region: 0.006s
# [Total for image 58: 17.017s]
#
# Processing image 59/100
#   - Read image: 0.337s
#     - Construct path: 0.000s
#     - Read from disk: 0.267s
#     - Resize: 0.025s
#     - Convert to RGBA: 0.041s
#   - Expand search region: 0.342s
#   - Find matches: 15.002s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.017s
#     - SIFT detection: 9.345s
#     - FLANN matching: 5.009s
#     - Filter matches: 0.021s
#     - Extract points: 0.132s
#   - Align images: 0.000s
#   - Warp and overlay: 0.824s
#   - Crop result: 0.337s
#   - Update match region: 0.001s
# [Total for image 59: 16.844s]
#
# Processing image 60/100
#   - Read image: 0.307s
#     - Construct path: 0.000s
#     - Read from disk: 0.250s
#     - Resize: 0.023s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.285s
#   - Find matches: 15.520s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.013s
#     - SIFT detection: 9.640s
#     - FLANN matching: 5.329s
#     - Filter matches: 0.021s
#     - Extract points: 0.150s
#   - Align images: 0.010s
#   - Warp and overlay: 0.928s
#   - Crop result: 0.320s
#   - Update match region: 0.008s
# [Total for image 60: 17.380s]
#   - Saved result_60.png
#
# Processing image 61/100
#   - Read image: 0.320s
#     - Construct path: 0.000s
#     - Read from disk: 0.262s
#     - Resize: 0.025s
#     - Convert to RGBA: 0.031s
#   - Expand search region: 0.366s
#   - Find matches: 15.991s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.018s
#     - SIFT detection: 10.525s
#     - FLANN matching: 4.856s
#     - Filter matches: 0.019s
#     - Extract points: 0.124s
#   - Align images: 0.002s
#   - Warp and overlay: 0.889s
#   - Crop result: 0.337s
#   - Update match region: 0.001s
# [Total for image 61: 17.908s]
#
# Processing image 62/100
#   - Read image: 0.319s
#     - Construct path: 0.000s
#     - Read from disk: 0.260s
#     - Resize: 0.024s
#     - Convert to RGBA: 0.034s
#   - Expand search region: 0.290s
#   - Find matches: 14.734s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.013s
#     - SIFT detection: 8.985s
#     - FLANN matching: 5.180s
#     - Filter matches: 0.022s
#     - Extract points: 0.146s
#   - Align images: 0.009s
#   - Warp and overlay: 0.765s
#   - Crop result: 0.328s
#   - Update match region: 0.007s
# [Total for image 62: 16.454s]
#
# Processing image 63/100
#   - Read image: 0.333s
#     - Construct path: 0.001s
#     - Read from disk: 0.274s
#     - Resize: 0.026s
#     - Convert to RGBA: 0.031s
#   - Expand search region: 0.374s
#   - Find matches: 14.546s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.015s
#     - SIFT detection: 8.974s
#     - FLANN matching: 4.824s
#     - Filter matches: 0.021s
#     - Extract points: 0.134s
#   - Align images: 0.010s
#   - Warp and overlay: 0.954s
#   - Crop result: 0.373s
#   - Update match region: 0.005s
# [Total for image 63: 16.596s]
#
# Processing image 64/100
#   - Read image: 0.328s
#     - Construct path: 0.000s
#     - Read from disk: 0.268s
#     - Resize: 0.026s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.317s
#   - Find matches: 16.016s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.017s
#     - SIFT detection: 10.446s
#     - FLANN matching: 5.031s
#     - Filter matches: 0.021s
#     - Extract points: 0.139s
#   - Align images: 0.012s
#   - Warp and overlay: 0.843s
#   - Crop result: 0.330s
#   - Update match region: 0.006s
# [Total for image 64: 17.855s]
#
# Processing image 65/100
#   - Read image: 0.321s
#     - Construct path: 0.000s
#     - Read from disk: 0.259s
#     - Resize: 0.027s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.422s
#   - Find matches: 16.118s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.018s
#     - SIFT detection: 10.673s
#     - FLANN matching: 4.745s
#     - Filter matches: 0.018s
#     - Extract points: 0.136s
#   - Align images: 0.010s
#   - Warp and overlay: 0.939s
#   - Crop result: 0.379s
#   - Update match region: 0.007s
# [Total for image 65: 18.198s]
#
# Processing image 66/100
#   - Read image: 0.313s
#     - Construct path: 0.000s
#     - Read from disk: 0.254s
#     - Resize: 0.026s
#     - Convert to RGBA: 0.031s
#   - Expand search region: 0.330s
#   - Find matches: 14.658s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.017s
#     - SIFT detection: 9.286s
#     - FLANN matching: 4.781s
#     - Filter matches: 0.020s
#     - Extract points: 0.139s
#   - Align images: 0.009s
#   - Warp and overlay: 0.953s
#   - Crop result: 0.362s
#   - Update match region: 0.007s
# [Total for image 66: 16.632s]
#
# Processing image 67/100
#   - Read image: 0.327s
#     - Construct path: 0.001s
#     - Read from disk: 0.263s
#     - Resize: 0.028s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.413s
#   - Find matches: 14.689s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.018s
#     - SIFT detection: 9.573s
#     - FLANN matching: 4.414s
#     - Filter matches: 0.017s
#     - Extract points: 0.125s
#   - Align images: 0.010s
#   - Warp and overlay: 1.024s
#   - Crop result: 0.385s
#   - Update match region: 0.005s
# [Total for image 67: 16.857s]
#
# Processing image 68/100
#   - Read image: 0.331s
#     - Construct path: 0.000s
#     - Read from disk: 0.271s
#     - Resize: 0.026s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.337s
#   - Find matches: 14.512s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.017s
#     - SIFT detection: 9.256s
#     - FLANN matching: 4.643s
#     - Filter matches: 0.018s
#     - Extract points: 0.130s
#   - Align images: 0.009s
#   - Warp and overlay: 0.884s
#   - Crop result: 0.351s
#   - Update match region: 0.006s
# [Total for image 68: 16.432s]
#
# Processing image 69/100
#   - Read image: 0.340s
#     - Construct path: 0.000s
#     - Read from disk: 0.279s
#     - Resize: 0.027s
#     - Convert to RGBA: 0.032s
#   - Expand search region: 0.470s
#   - Find matches: 14.563s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.018s
#     - SIFT detection: 9.330s
#     - FLANN matching: 4.431s
#     - Filter matches: 0.018s
#     - Extract points: 0.130s
#   - Align images: 0.011s
#   - Warp and overlay: 1.153s
#   - Crop result: 0.412s
#   - Update match region: 0.010s
# [Total for image 69: 16.960s]
#
# Processing image 70/100
#   - Read image: 0.334s
#     - Construct path: 0.001s
#     - Read from disk: 0.271s
#     - Resize: 0.025s
#     - Convert to RGBA: 0.033s
#   - Expand search region: 0.361s
#   - Find matches: 14.925s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.016s
#     - SIFT detection: 9.703s
#     - FLANN matching: 4.620s
#     - Filter matches: 0.017s
#     - Extract points: 0.134s
#   - Align images: 0.011s
#   - Warp and overlay: 0.938s
#   - Crop result: 0.377s
#   - Update match region: 0.007s
# [Total for image 70: 16.958s]
#   - Saved result_70.png
#
# Processing image 71/100
#   - Read image: 0.334s
#     - Construct path: 0.001s
#     - Read from disk: 0.273s
#     - Resize: 0.025s
#     - Convert to RGBA: 0.034s
#   - Expand search region: 0.444s
#   - Find matches: 14.599s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.016s
#     - SIFT detection: 9.420s
#     - FLANN matching: 4.444s
#     - Filter matches: 0.016s
#     - Extract points: 0.137s
#   - Align images: 0.010s
#   - Warp and overlay: 1.050s
#   - Crop result: 0.437s
#   - Update match region: 0.004s
# [Total for image 71: 16.881s]
#
# Processing image 72/100
