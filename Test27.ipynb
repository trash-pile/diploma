# %%
import cv2
import numpy as np
from dataclasses import dataclass
from time import time
from typing import Tuple, Optional
from pathlib import Path
import numba
from concurrent.futures import ThreadPoolExecutor, Future
import os

@dataclass(frozen=True)
class Config:
    SCALE: float = 0.4
    NFEAT: int = 50000
    MATCH_RATIO: float = 0.65
    KEEP_PERCENT: float = 0.55
    THRESH: float = 250.0
    SIFT_EDGE_THRESHOLD: float = 10.0
    SIFT_CONTRAST_THRESHOLD: float = 0.04
    NUM_THREADS: int = os.cpu_count() if os.cpu_count() else 4
    SEARCH_FIELD_MULTIPLIER: float = 1.6

class ImageStitcher:
    def __init__(self, path: str = "./folder2/"):
        self.path = Path(path)
        if Config.SEARCH_FIELD_MULTIPLIER < 1.0:
            raise ValueError("SEARCH_FIELD_MULTIPLIER must be >= 1.0")
        self.sift = cv2.SIFT_create(
            nfeatures=Config.NFEAT,
            contrastThreshold=Config.SIFT_CONTRAST_THRESHOLD,
            edgeThreshold=Config.SIFT_EDGE_THRESHOLD
        )
        self.matcher = cv2.FlannBasedMatcher(dict(algorithm=1, trees=5), dict(checks=32))
        self.last_match_region: Optional[Tuple[int, int]] = None
        self._gray_buffer1: Optional[np.ndarray] = None
        self._gray_buffer2: Optional[np.ndarray] = None
        self._base_image_size: Optional[Tuple[int, int]] = None
        self._canvas_offset: Tuple[int, int] = (0, 0)
        print(f"Using {Config.NUM_THREADS} worker threads")
        self.thread_pool = ThreadPoolExecutor(max_workers=Config.NUM_THREADS)

    def read_image(self, idx: int) -> Tuple[np.ndarray, dict]:
        timings = {}
        path_start = time()
        img_path = self.path / f"2023_09_01_SonyRX1RM2_g201b20538_f001_{idx:04}.JPG"
        timings['construct_path'] = time() - path_start
        read_start = time()
        img = cv2.imread(str(img_path), cv2.IMREAD_COLOR)
        timings['read_from_disk'] = time() - read_start
        resize_start = time()
        img = cv2.resize(img, None, fx=Config.SCALE, fy=Config.SCALE, interpolation=cv2.INTER_LINEAR)
        timings['resize'] = time() - resize_start
        if self._base_image_size is None:
            self._base_image_size = (img.shape[1], img.shape[0])
        rgba_start = time()
        rgba = np.zeros((img.shape[0], img.shape[1], 4), dtype=np.uint8)
        rgba[:, :, :3] = img
        rgba[:, :, 3] = 255
        timings['convert_to_rgba'] = time() - rgba_start
        return rgba, timings

    def get_search_region_and_expand(self, img: np.ndarray) -> Tuple[np.ndarray, Tuple[int, int, int, int], Tuple[int, int]]:
        h, w = img.shape[:2]
        if self.last_match_region is None:
            self.last_match_region = (w // 2, h // 2)
            return img, (0, 0, w, h), (0, 0)
        base_w, base_h = self._base_image_size
        search_w = int(round(base_w * Config.SEARCH_FIELD_MULTIPLIER**2))
        search_h = int(round(base_h * Config.SEARCH_FIELD_MULTIPLIER**2))
        search_w = max(base_w, search_w)
        search_h = max(base_h, search_h)
        cx, cy = self.last_match_region
        x1 = int(round(cx - search_w / 2))
        y1 = int(round(cy - search_h / 2))
        x2 = x1 + search_w
        y2 = y1 + search_h
        pad_left = max(0, -x1)
        pad_right = max(0, x2 - w)
        pad_top = max(0, -y1)
        pad_bottom = max(0, y2 - h)
        max_pad_w = int(round(base_w * Config.SEARCH_FIELD_MULTIPLIER**2))
        max_pad_h = int(round(base_h * Config.SEARCH_FIELD_MULTIPLIER**2))
        pad_left = min(pad_left, max_pad_w)
        pad_right = min(pad_right, max_pad_w)
        pad_top = min(pad_top, max_pad_h)
        pad_bottom = min(pad_bottom, max_pad_h)
        if pad_left or pad_right or pad_top or pad_bottom:
            new_w = w + pad_left + pad_right
            new_h = h + pad_top + pad_bottom
            canvas = np.zeros((new_h, new_w, 4), dtype=np.uint8)
            canvas[pad_top:pad_top + h, pad_left:pad_left + w] = img
            x1 += pad_left
            x2 += pad_left
            y1 += pad_top
            y2 += pad_top
            result_img = canvas
            offset = (pad_left, pad_top)
            self._canvas_offset = (self._canvas_offset[0] + pad_left, self._canvas_offset[1] + pad_top)
        else:
            result_img = img
            offset = (0, 0)
        x1 = max(0, x1)
        y1 = max(0, y1)
        x2 = min(result_img.shape[1], x2)
        y2 = min(result_img.shape[0], y2)
        return result_img, (x1, y1, x2, y2), offset

    def update_last_match_region(self, matrix: np.ndarray, img_shape: Tuple[int, int], 
                                 offset: Tuple[int, int], crop_offset: Optional[Tuple[int, int]] = None):
        h, w = img_shape[:2]
        center = np.array([[w/2], [h/2], [1]], dtype=np.float32)
        transformed = matrix @ center
        new_cx = int(transformed[0, 0]) + offset[0]
        new_cy = int(transformed[1, 0]) + offset[1]
        if crop_offset:
            new_cx -= crop_offset[0]
            new_cy -= crop_offset[1]
        self.last_match_region = (new_cx, new_cy)

    def find_matches(self, img1: np.ndarray, img2: np.ndarray) -> Tuple[np.ndarray, np.ndarray, np.ndarray, Tuple[int, int], dict]:
        timings = {}
        img1, (x1, y1, x2, y2), offset = self.get_search_region_and_expand(img1)
        if x2 <= x1 or y2 <= y1:
            raise ValueError(f"Invalid search region: x1={x1}, x2={x2}, y1={y1}, y2={y2}")
        roi_start = time()
        img1_roi = img1[y1:y2, x1:x2]
        timings['extract_roi'] = time() - roi_start
        buffer_start = time()
        if self._gray_buffer1 is None or self._gray_buffer1.shape != img1_roi.shape[:2]:
            self._gray_buffer1 = np.empty(img1_roi.shape[:2], dtype=np.uint8)
        if self._gray_buffer2 is None or self._gray_buffer2.shape != img2.shape[:2]:
            self._gray_buffer2 = np.empty(img2.shape[:2], dtype=np.uint8)
        timings['allocate_buffers'] = time() - buffer_start
        gray_start = time()
        futures = [
            self.thread_pool.submit(cv2.cvtColor, img1_roi, cv2.COLOR_BGRA2GRAY, dst=self._gray_buffer1),
            self.thread_pool.submit(cv2.cvtColor, img2, cv2.COLOR_BGRA2GRAY, dst=self._gray_buffer2)
        ]
        for future in futures:
            future.result()
        timings['convert_to_grayscale'] = time() - gray_start
        def detect_compute(img, sift):
            return sift.detectAndCompute(img, None)
        sift_start = time()
        future_kp1 = self.thread_pool.submit(detect_compute, self._gray_buffer1, self.sift)
        future_kp2 = self.thread_pool.submit(detect_compute, self._gray_buffer2, self.sift)
        kp1, desc1 = future_kp1.result()
        kp2, desc2 = future_kp2.result()
        timings['sift_detection'] = time() - sift_start
        flann_start = time()
        matches = self.matcher.knnMatch(desc1, desc2, k=2)
        timings['flann_matching'] = time() - flann_start
        filter_start = time()
        good = [m for m, n in matches if m.distance < Config.MATCH_RATIO * n.distance]
        good = sorted(good, key=lambda x: x.distance)[:int(len(good) * Config.KEEP_PERCENT)]
        timings['filter_matches'] = time() - filter_start
        points_start = time()
        query_idx = np.array([m.queryIdx for m in good])
        train_idx = np.array([m.trainIdx for m in good])
        pts1 = np.float32([kp.pt for kp in kp1])[query_idx] + [x1, y1]
        pts2 = np.float32([kp.pt for kp in kp2])[train_idx]
        timings['extract_points'] = time() - points_start
        return img1, pts1, pts2, offset, timings

    def align_images(self, pts1: np.ndarray, pts2: np.ndarray, 
                     img_shape: Tuple[int, int], offset: Tuple[int, int]) -> np.ndarray:
        matrix, _ = cv2.estimateAffinePartial2D(
            pts2, pts1,
            method=cv2.RANSAC,
            ransacReprojThreshold=Config.THRESH,
            confidence=0.995,
            maxIters=1000
        )
        if matrix is not None:
            # Extract linear part
            L = matrix[:, :2]
            # Compute scaling factors
            s_x = np.linalg.norm(L[:, 0])
            s_y = np.linalg.norm(L[:, 1])
            s_avg = (s_x + s_y) / 2
            if s_avg > 0:
                # Normalize linear part to remove scaling
                matrix[:, :2] /= s_avg
                print(f"Adjusted scaling factor from {s_avg:.4f} to 1.0")
            else:
                print("Warning: s_avg is zero, cannot adjust scaling")
        else:
            print("Warning: No transformation matrix found")
        return matrix

    @staticmethod
    @numba.jit(nopython=True, parallel=True)
    def overlay_images_numba(base: np.ndarray, overlay: np.ndarray, result: np.ndarray):
        h, w = base.shape[:2]
        for y in numba.prange(h):
            for x in range(w):
                if overlay[y, x, 3] > 0:
                    result[y, x] = overlay[y, x]
                else:
                    result[y, x] = base[y, x]

    def overlay_images(self, base: np.ndarray, overlay: np.ndarray) -> np.ndarray:
        result = np.zeros_like(base, dtype=np.uint8)
        ImageStitcher.overlay_images_numba(base, overlay, result)
        return result

    def crop_result(self, img: np.ndarray) -> Tuple[np.ndarray, Tuple[int, int]]:
        mask = img[:, :, 3] > 0
        rows = np.any(mask, axis=1)
        cols = np.any(mask, axis=0)
        y1, y2 = np.where(rows)[0][[0, -1]]
        x1, x2 = np.where(cols)[0][[0, -1]]
        crop_offset = (x1, y1)
        return img[y1:y2+1, x1:x2+1], crop_offset

    def stitch(self, start: int = 3, end: int = 100):
        print(f"\nStarting image stitching process from {start} to {end}")
        start_time = time()
        result, read_timings = self.read_image(start)
        print(f"  - Read initial image: {time() - start_time:.3f}s")
        expand_start = time()
        result, _, offset = self.get_search_region_and_expand(result)
        expand_time = time() - expand_start
        print(f"  - Expand initial image: {expand_time:.3f}s")
        future: Optional[Future] = None
        for idx in range(start + 1, end + 1):
            iter_start = time()
            print(f"\nProcessing image {idx}/{end}")
            if future is not None:
                current, read_timings = future.result()
            else:
                current, read_timings = self.read_image(idx)
            if idx < end:
                future = self.thread_pool.submit(self.read_image, idx + 1)
            match_start = time()
            result, pts1, pts2, offset, match_timings = self.find_matches(result, current)
            match_time = time() - match_start
            align_start = time()
            matrix = self.align_images(pts1, pts2, current.shape, offset)
            align_time = time() - align_start
            warp_start = time()
            aligned = cv2.warpAffine(
                current, matrix,
                (result.shape[1], result.shape[0]),
                flags=cv2.INTER_LINEAR,
                borderMode=cv2.BORDER_TRANSPARENT
            )
            result = self.overlay_images(result, aligned)
            warp_time = time() - warp_start
            crop_start = time()
            result, crop_offset = self.crop_result(result)
            crop_time = time() - crop_start
            update_start = time()
            self.update_last_match_region(matrix, current.shape, offset, crop_offset)
            update_time = time() - update_start
            print(f"  - Find matches: {match_time:.3f}s")
            print(f"    - Extract ROI: {match_timings['extract_roi']:.3f}s")
            print(f"    - Allocate buffers: {match_timings['allocate_buffers']:.3f}s")
            print(f"    - Convert to grayscale: {match_timings['convert_to_grayscale']:.3f}s")
            print(f"    - SIFT detection: {match_timings['sift_detection']:.3f}s")
            print(f"    - FLANN matching: {match_timings['flann_matching']:.3f}s")
            print(f"    - Filter matches: {match_timings['filter_matches']:.3f}s")
            print(f"    - Extract points: {match_timings['extract_points']:.3f}s")
            print(f"  - Align images: {align_time:.3f}s")
            print(f"  - Warp and overlay: {warp_time:.3f}s")
            print(f"  - Crop result: {crop_time:.3f}s")
            print(f"  - Update match region: {update_time:.3f}s")
            print(f"[Total for image {idx}: {time() - iter_start:.3f}s]")
            if idx % 10 == 0:
                cv2.imwrite(f"result_{idx}.png", result)
                print(f"  - Saved result_{idx}.png")
        total_time = time() - start_time
        print(f"\nStitching completed in {total_time:.3f}s")

    def __del__(self):
        self.thread_pool.shutdown()

if __name__ == "__main__":
    stitcher = ImageStitcher()
    stitcher.stitch()
# Out:
# Using 16 worker threads
#
# Starting image stitching process from 3 to 100
#   - Read initial image: 0.345s
#   - Expand initial image: 0.000s
#
# Processing image 4/100
# Adjusted scaling factor from 0.9907 to 1.0
#   - Find matches: 8.782s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.017s
#     - SIFT detection: 7.005s
#     - FLANN matching: 1.685s
#     - Filter matches: 0.007s
#     - Extract points: 0.049s
#   - Align images: 0.005s
#   - Warp and overlay: 1.585s
#   - Crop result: 0.036s
#   - Update match region: 0.001s
# [Total for image 4: 10.704s]
#
# Processing image 5/100
# Adjusted scaling factor from 0.9581 to 1.0
#   - Find matches: 9.689s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 7.817s
#     - FLANN matching: 1.731s
#     - Filter matches: 0.007s
#     - Extract points: 0.098s
#   - Align images: 0.001s
#   - Warp and overlay: 0.107s
#   - Crop result: 0.043s
#   - Update match region: 0.000s
# [Total for image 5: 9.841s]
#
# Processing image 6/100
# Adjusted scaling factor from 1.0270 to 1.0
#   - Find matches: 9.414s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 7.661s
#     - FLANN matching: 1.659s
#     - Filter matches: 0.007s
#     - Extract points: 0.046s
#   - Align images: 0.000s
#   - Warp and overlay: 0.098s
#   - Crop result: 0.036s
#   - Update match region: 0.000s
# [Total for image 6: 9.549s]
#
# Processing image 7/100
# Adjusted scaling factor from 0.9912 to 1.0
#   - Find matches: 9.955s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 8.199s
#     - FLANN matching: 1.652s
#     - Filter matches: 0.007s
#     - Extract points: 0.047s
#   - Align images: 0.000s
#   - Warp and overlay: 0.129s
#   - Crop result: 0.044s
#   - Update match region: 0.000s
# [Total for image 7: 10.129s]
#
# Processing image 8/100
# Adjusted scaling factor from 1.0076 to 1.0
#   - Find matches: 10.014s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 8.249s
#     - FLANN matching: 1.662s
#     - Filter matches: 0.007s
#     - Extract points: 0.047s
#   - Align images: 0.001s
#   - Warp and overlay: 0.113s
#   - Crop result: 0.042s
#   - Update match region: 0.000s
# [Total for image 8: 10.171s]
#
# Processing image 9/100
# Adjusted scaling factor from 0.9842 to 1.0
#   - Find matches: 9.851s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 8.058s
#     - FLANN matching: 1.684s
#     - Filter matches: 0.006s
#     - Extract points: 0.047s
#   - Align images: 0.001s
#   - Warp and overlay: 0.118s
#   - Crop result: 0.041s
#   - Update match region: 0.000s
# [Total for image 9: 10.012s]
#
# Processing image 10/100
# Adjusted scaling factor from 1.0202 to 1.0
#   - Find matches: 9.681s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 7.890s
#     - FLANN matching: 1.678s
#     - Filter matches: 0.007s
#     - Extract points: 0.048s
#   - Align images: 0.001s
#   - Warp and overlay: 0.132s
#   - Crop result: 0.050s
#   - Update match region: 0.000s
# [Total for image 10: 9.866s]
#   - Saved result_10.png
#
# Processing image 11/100
# Adjusted scaling factor from 0.9706 to 1.0
#   - Find matches: 9.426s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 7.656s
#     - FLANN matching: 1.651s
#     - Filter matches: 0.006s
#     - Extract points: 0.047s
#   - Align images: 0.000s
#   - Warp and overlay: 0.131s
#   - Crop result: 0.045s
#   - Update match region: 0.000s
# [Total for image 11: 9.604s]
#
# Processing image 12/100
# Adjusted scaling factor from 0.9928 to 1.0
#   - Find matches: 9.266s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 7.451s
#     - FLANN matching: 1.695s
#     - Filter matches: 0.007s
#     - Extract points: 0.047s
#   - Align images: 0.000s
#   - Warp and overlay: 0.161s
#   - Crop result: 0.058s
#   - Update match region: 0.000s
# [Total for image 12: 9.486s]
#
# Processing image 13/100
# Adjusted scaling factor from 1.0009 to 1.0
#   - Find matches: 10.058s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 8.252s
#     - FLANN matching: 1.676s
#     - Filter matches: 0.007s
#     - Extract points: 0.049s
#   - Align images: 0.001s
#   - Warp and overlay: 0.153s
#   - Crop result: 0.055s
#   - Update match region: 0.000s
# [Total for image 13: 10.268s]
#
# Processing image 14/100
# Adjusted scaling factor from 1.0027 to 1.0
#   - Find matches: 9.639s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 7.821s
#     - FLANN matching: 1.684s
#     - Filter matches: 0.006s
#     - Extract points: 0.047s
#   - Align images: 0.000s
#   - Warp and overlay: 0.189s
#   - Crop result: 0.069s
#   - Update match region: 0.000s
# [Total for image 14: 9.898s]
#
# Processing image 15/100
# Adjusted scaling factor from 1.0174 to 1.0
#   - Find matches: 9.835s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 8.037s
#     - FLANN matching: 1.663s
#     - Filter matches: 0.007s
#     - Extract points: 0.046s
#   - Align images: 0.000s
#   - Warp and overlay: 0.173s
#   - Crop result: 0.064s
#   - Update match region: 0.000s
# [Total for image 15: 10.073s]
#
# Processing image 16/100
# Adjusted scaling factor from 0.9872 to 1.0
#   - Find matches: 10.171s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.014s
#     - SIFT detection: 8.366s
#     - FLANN matching: 1.660s
#     - Filter matches: 0.007s
#     - Extract points: 0.046s
#   - Align images: 0.000s
#   - Warp and overlay: 0.182s
#   - Crop result: 0.068s
#   - Update match region: 0.000s
# [Total for image 16: 10.422s]
#
# Processing image 17/100
# Adjusted scaling factor from 0.9842 to 1.0
#   - Find matches: 10.199s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 8.313s
#     - FLANN matching: 1.742s
#     - Filter matches: 0.007s
#     - Extract points: 0.045s
#   - Align images: 0.000s
#   - Warp and overlay: 0.180s
#   - Crop result: 0.064s
#   - Update match region: 0.000s
# [Total for image 17: 10.445s]
#
# Processing image 18/100
# Adjusted scaling factor from 0.9882 to 1.0
#   - Find matches: 10.586s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 8.732s
#     - FLANN matching: 1.713s
#     - Filter matches: 0.007s
#     - Extract points: 0.045s
#   - Align images: 0.000s
#   - Warp and overlay: 0.185s
#   - Crop result: 0.064s
#   - Update match region: 0.000s
# [Total for image 18: 10.835s]
#
# Processing image 19/100
# Adjusted scaling factor from 0.9769 to 1.0
#   - Find matches: 10.601s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.012s
#     - SIFT detection: 8.699s
#     - FLANN matching: 1.760s
#     - Filter matches: 0.006s
#     - Extract points: 0.046s
#   - Align images: 0.001s
#   - Warp and overlay: 0.203s
#   - Crop result: 0.066s
#   - Update match region: 0.000s
# [Total for image 19: 10.872s]
#
# Processing image 20/100
# Adjusted scaling factor from 1.0030 to 1.0
#   - Find matches: 10.977s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 9.084s
#     - FLANN matching: 1.754s
#     - Filter matches: 0.007s
#     - Extract points: 0.046s
#   - Align images: 0.000s
#   - Warp and overlay: 0.185s
#   - Crop result: 0.072s
#   - Update match region: 0.000s
# [Total for image 20: 11.235s]
#   - Saved result_20.png
#
# Processing image 21/100
# Adjusted scaling factor from 0.9871 to 1.0
#   - Find matches: 10.578s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 8.704s
#     - FLANN matching: 1.729s
#     - Filter matches: 0.007s
#     - Extract points: 0.048s
#   - Align images: 0.001s
#   - Warp and overlay: 0.176s
#   - Crop result: 0.073s
#   - Update match region: 0.000s
# [Total for image 21: 10.829s]
#
# Processing image 22/100
# Adjusted scaling factor from 0.9891 to 1.0
#   - Find matches: 10.617s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.017s
#     - SIFT detection: 8.730s
#     - FLANN matching: 1.735s
#     - Filter matches: 0.007s
#     - Extract points: 0.047s
#   - Align images: 0.000s
#   - Warp and overlay: 0.188s
#   - Crop result: 0.069s
#   - Update match region: 0.000s
# [Total for image 22: 10.875s]
#
# Processing image 23/100
# Adjusted scaling factor from 0.9794 to 1.0
#   - Find matches: 11.093s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.014s
#     - SIFT detection: 9.095s
#     - FLANN matching: 1.837s
#     - Filter matches: 0.007s
#     - Extract points: 0.057s
#   - Align images: 0.014s
#   - Warp and overlay: 0.219s
#   - Crop result: 0.071s
#   - Update match region: 0.004s
# [Total for image 23: 11.402s]
#
# Processing image 24/100
# Adjusted scaling factor from 0.9924 to 1.0
#   - Find matches: 10.400s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.022s
#     - SIFT detection: 8.530s
#     - FLANN matching: 1.710s
#     - Filter matches: 0.006s
#     - Extract points: 0.046s
#   - Align images: 0.001s
#   - Warp and overlay: 0.185s
#   - Crop result: 0.061s
#   - Update match region: 0.000s
# [Total for image 24: 10.650s]
#
# Processing image 25/100
# Adjusted scaling factor from 0.9700 to 1.0
#   - Find matches: 9.789s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 7.938s
#     - FLANN matching: 1.705s
#     - Filter matches: 0.007s
#     - Extract points: 0.047s
#   - Align images: 0.001s
#   - Warp and overlay: 0.191s
#   - Crop result: 0.071s
#   - Update match region: 0.000s
# [Total for image 25: 10.052s]
#
# Processing image 26/100
# Adjusted scaling factor from 0.9911 to 1.0
#   - Find matches: 10.157s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 8.324s
#     - FLANN matching: 1.691s
#     - Filter matches: 0.007s
#     - Extract points: 0.045s
#   - Align images: 0.000s
#   - Warp and overlay: 0.190s
#   - Crop result: 0.076s
#   - Update match region: 0.000s
# [Total for image 26: 10.424s]
#
# Processing image 27/100
# Adjusted scaling factor from 1.0065 to 1.0
#   - Find matches: 10.362s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.010s
#     - SIFT detection: 8.330s
#     - FLANN matching: 1.878s
#     - Filter matches: 0.008s
#     - Extract points: 0.047s
#   - Align images: 0.001s
#   - Warp and overlay: 0.205s
#   - Crop result: 0.076s
#   - Update match region: 0.000s
# [Total for image 27: 10.646s]
#
# Processing image 28/100
# Adjusted scaling factor from 0.9769 to 1.0
#   - Find matches: 10.087s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 8.283s
#     - FLANN matching: 1.641s
#     - Filter matches: 0.007s
#     - Extract points: 0.045s
#   - Align images: 0.000s
#   - Warp and overlay: 0.216s
#   - Crop result: 0.085s
#   - Update match region: 0.000s
# [Total for image 28: 10.389s]
#
# Processing image 29/100
# Adjusted scaling factor from 0.9712 to 1.0
#   - Find matches: 10.146s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.009s
#     - SIFT detection: 8.311s
#     - FLANN matching: 1.669s
#     - Filter matches: 0.007s
#     - Extract points: 0.045s
#   - Align images: 0.000s
#   - Warp and overlay: 0.218s
#   - Crop result: 0.094s
#   - Update match region: 0.000s
# [Total for image 29: 10.459s]
#
# Processing image 30/100
# Adjusted scaling factor from 0.9788 to 1.0
#   - Find matches: 10.392s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 8.576s
#     - FLANN matching: 1.642s
#     - Filter matches: 0.007s
#     - Extract points: 0.045s
#   - Align images: 0.000s
#   - Warp and overlay: 0.285s
#   - Crop result: 0.083s
#   - Update match region: 0.000s
# [Total for image 30: 10.761s]
#   - Saved result_30.png
#
# Processing image 31/100
# Adjusted scaling factor from 0.9657 to 1.0
#   - Find matches: 10.586s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.009s
#     - SIFT detection: 8.768s
#     - FLANN matching: 1.651s
#     - Filter matches: 0.006s
#     - Extract points: 0.045s
#   - Align images: 0.001s
#   - Warp and overlay: 0.234s
#   - Crop result: 0.091s
#   - Update match region: 0.000s
# [Total for image 31: 10.914s]
#
# Processing image 32/100
# Adjusted scaling factor from 1.0013 to 1.0
#   - Find matches: 10.159s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 8.332s
#     - FLANN matching: 1.675s
#     - Filter matches: 0.007s
#     - Extract points: 0.045s
#   - Align images: 0.001s
#   - Warp and overlay: 0.214s
#   - Crop result: 0.087s
#   - Update match region: 0.000s
# [Total for image 32: 10.462s]
#
# Processing image 33/100
# Adjusted scaling factor from 0.9973 to 1.0
#   - Find matches: 10.333s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 8.432s
#     - FLANN matching: 1.691s
#     - Filter matches: 0.007s
#     - Extract points: 0.045s
#   - Align images: 0.000s
#   - Warp and overlay: 0.303s
#   - Crop result: 0.112s
#   - Update match region: 0.000s
# [Total for image 33: 10.749s]
#
# Processing image 34/100
# Adjusted scaling factor from 0.9780 to 1.0
#   - Find matches: 10.345s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 8.515s
#     - FLANN matching: 1.670s
#     - Filter matches: 0.007s
#     - Extract points: 0.044s
#   - Align images: 0.000s
#   - Warp and overlay: 0.255s
#   - Crop result: 0.106s
#   - Update match region: 0.000s
# [Total for image 34: 10.710s]
#
# Processing image 35/100
# Adjusted scaling factor from 0.9740 to 1.0
#   - Find matches: 10.217s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.012s
#     - SIFT detection: 8.326s
#     - FLANN matching: 1.654s
#     - Filter matches: 0.007s
#     - Extract points: 0.044s
#   - Align images: 0.001s
#   - Warp and overlay: 0.362s
#   - Crop result: 0.132s
#   - Update match region: 0.000s
# [Total for image 35: 10.713s]
#
# Processing image 36/100
# Adjusted scaling factor from 0.9757 to 1.0
#   - Find matches: 10.482s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.012s
#     - SIFT detection: 8.640s
#     - FLANN matching: 1.658s
#     - Filter matches: 0.007s
#     - Extract points: 0.045s
#   - Align images: 0.001s
#   - Warp and overlay: 0.309s
#   - Crop result: 0.125s
#   - Update match region: 0.000s
# [Total for image 36: 10.919s]
#
# Processing image 37/100
# Adjusted scaling factor from 0.9803 to 1.0
#   - Find matches: 10.441s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.012s
#     - SIFT detection: 8.465s
#     - FLANN matching: 1.708s
#     - Filter matches: 0.008s
#     - Extract points: 0.046s
#   - Align images: 0.001s
#   - Warp and overlay: 0.424s
#   - Crop result: 0.153s
#   - Update match region: 0.001s
# [Total for image 37: 11.021s]
#
# Processing image 38/100
# Adjusted scaling factor from 0.9843 to 1.0
#   - Find matches: 12.056s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 10.106s
#     - FLANN matching: 1.719s
#     - Filter matches: 0.008s
#     - Extract points: 0.057s
#   - Align images: 0.014s
#   - Warp and overlay: 0.384s
#   - Crop result: 0.152s
#   - Update match region: 0.005s
# [Total for image 38: 12.614s]
#
# Processing image 39/100
# Adjusted scaling factor from 0.9722 to 1.0
#   - Find matches: 10.793s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.046s
#     - SIFT detection: 8.810s
#     - FLANN matching: 1.653s
#     - Filter matches: 0.007s
#     - Extract points: 0.046s
#   - Align images: 0.001s
#   - Warp and overlay: 0.468s
#   - Crop result: 0.175s
#   - Update match region: 0.000s
# [Total for image 39: 11.439s]
#
# Processing image 40/100
# Adjusted scaling factor from 0.9869 to 1.0
#   - Find matches: 10.629s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 8.705s
#     - FLANN matching: 1.690s
#     - Filter matches: 0.008s
#     - Extract points: 0.047s
#   - Align images: 0.002s
#   - Warp and overlay: 0.426s
#   - Crop result: 0.166s
#   - Update match region: 0.000s
# [Total for image 40: 11.226s]
#   - Saved result_40.png
#
# Processing image 41/100
# Adjusted scaling factor from 0.9788 to 1.0
#   - Find matches: 11.643s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.018s
#     - SIFT detection: 9.636s
#     - FLANN matching: 1.674s
#     - Filter matches: 0.007s
#     - Extract points: 0.046s
#   - Align images: 0.001s
#   - Warp and overlay: 0.534s
#   - Crop result: 0.203s
#   - Update match region: 0.000s
# [Total for image 41: 12.381s]
#
# Processing image 42/100
# Adjusted scaling factor from 0.9814 to 1.0
#   - Find matches: 11.733s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.012s
#     - SIFT detection: 9.831s
#     - FLANN matching: 1.654s
#     - Filter matches: 0.008s
#     - Extract points: 0.046s
#   - Align images: 0.001s
#   - Warp and overlay: 0.464s
#   - Crop result: 0.183s
#   - Update match region: 0.000s
# [Total for image 42: 12.385s]
#
# Processing image 43/100
# Adjusted scaling factor from 0.9800 to 1.0
#   - Find matches: 10.569s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.012s
#     - SIFT detection: 8.518s
#     - FLANN matching: 1.678s
#     - Filter matches: 0.006s
#     - Extract points: 0.045s
#   - Align images: 0.001s
#   - Warp and overlay: 0.618s
#   - Crop result: 0.231s
#   - Update match region: 0.000s
# [Total for image 43: 11.420s]
#
# Processing image 44/100
# Adjusted scaling factor from 0.9790 to 1.0
#   - Find matches: 10.691s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 8.774s
#     - FLANN matching: 1.652s
#     - Filter matches: 0.007s
#     - Extract points: 0.045s
#   - Align images: 0.001s
#   - Warp and overlay: 0.543s
#   - Crop result: 0.202s
#   - Update match region: 0.000s
# [Total for image 44: 11.442s]
#
# Processing image 45/100
# Adjusted scaling factor from 0.9753 to 1.0
#   - Find matches: 11.155s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 9.070s
#     - FLANN matching: 1.681s
#     - Filter matches: 0.007s
#     - Extract points: 0.047s
#   - Align images: 0.001s
#   - Warp and overlay: 0.694s
#   - Crop result: 0.247s
#   - Update match region: 0.000s
# [Total for image 45: 12.099s]
#
# Processing image 46/100
# Adjusted scaling factor from 0.9775 to 1.0
#   - Find matches: 11.138s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.011s
#     - SIFT detection: 9.171s
#     - FLANN matching: 1.675s
#     - Filter matches: 0.007s
#     - Extract points: 0.048s
#   - Align images: 0.002s
#   - Warp and overlay: 0.653s
#   - Crop result: 0.245s
#   - Update match region: 0.000s
# [Total for image 46: 12.042s]
#
# Processing image 47/100
# Adjusted scaling factor from 0.9813 to 1.0
#   - Find matches: 10.734s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.018s
#     - SIFT detection: 8.605s
#     - FLANN matching: 1.671s
#     - Filter matches: 0.008s
#     - Extract points: 0.048s
#   - Align images: 0.002s
#   - Warp and overlay: 0.769s
#   - Crop result: 0.282s
#   - Update match region: 0.000s
# [Total for image 47: 11.788s]
#
# Processing image 48/100
# Adjusted scaling factor from 0.9774 to 1.0
#   - Find matches: 11.898s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.012s
#     - SIFT detection: 9.879s
#     - FLANN matching: 1.683s
#     - Filter matches: 0.009s
#     - Extract points: 0.067s
#   - Align images: 0.026s
#   - Warp and overlay: 0.781s
#   - Crop result: 0.273s
#   - Update match region: 0.005s
# [Total for image 48: 12.985s]
#
# Processing image 49/100
# Adjusted scaling factor from 0.9781 to 1.0
#   - Find matches: 12.765s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.001s
#     - Convert to grayscale: 0.027s
#     - SIFT detection: 10.534s
#     - FLANN matching: 1.712s
#     - Filter matches: 0.007s
#     - Extract points: 0.048s
#   - Align images: 0.001s
#   - Warp and overlay: 0.868s
#   - Crop result: 0.319s
#   - Update match region: 0.000s
# [Total for image 49: 13.956s]
#
# Processing image 50/100
# Adjusted scaling factor from 0.9739 to 1.0
#   - Find matches: 12.979s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.022s
#     - SIFT detection: 10.965s
#     - FLANN matching: 1.662s
#     - Filter matches: 0.008s
#     - Extract points: 0.049s
#   - Align images: 0.002s
#   - Warp and overlay: 0.681s
#   - Crop result: 0.285s
#   - Update match region: 0.000s
# [Total for image 50: 13.948s]
#   - Saved result_50.png
#
# Processing image 51/100
# Adjusted scaling factor from 0.9812 to 1.0
#   - Find matches: 11.854s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.017s
#     - SIFT detection: 9.616s
#     - FLANN matching: 1.692s
#     - Filter matches: 0.008s
#     - Extract points: 0.048s
#   - Align images: 0.001s
#   - Warp and overlay: 0.936s
#   - Crop result: 0.327s
#   - Update match region: 0.001s
# [Total for image 51: 13.122s]
#
# Processing image 52/100
# Adjusted scaling factor from 0.9766 to 1.0
#   - Find matches: 12.879s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.025s
#     - SIFT detection: 10.572s
#     - FLANN matching: 1.891s
#     - Filter matches: 0.010s
#     - Extract points: 0.069s
#   - Align images: 0.031s
#   - Warp and overlay: 1.011s
#   - Crop result: 0.354s
#   - Update match region: 0.005s
# [Total for image 52: 14.282s]
#
# Processing image 53/100
# Adjusted scaling factor from 0.9751 to 1.0
#   - Find matches: 13.719s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.022s
#     - SIFT detection: 11.098s
#     - FLANN matching: 1.986s
#     - Filter matches: 0.010s
#     - Extract points: 0.074s
#   - Align images: 0.027s
#   - Warp and overlay: 1.141s
#   - Crop result: 0.476s
#   - Update match region: 0.005s
# [Total for image 53: 15.370s]
#
# Processing image 54/100
# Adjusted scaling factor from 0.9873 to 1.0
#   - Find matches: 13.800s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.030s
#     - SIFT detection: 11.072s
#     - FLANN matching: 2.103s
#     - Filter matches: 0.010s
#     - Extract points: 0.069s
#   - Align images: 0.028s
#   - Warp and overlay: 0.984s
#   - Crop result: 0.417s
#   - Update match region: 0.006s
# [Total for image 54: 15.238s]
#
# Processing image 55/100
# Adjusted scaling factor from 0.9765 to 1.0
#   - Find matches: 13.544s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.001s
#     - Convert to grayscale: 0.040s
#     - SIFT detection: 10.947s
#     - FLANN matching: 1.760s
#     - Filter matches: 0.009s
#     - Extract points: 0.069s
#   - Align images: 0.026s
#   - Warp and overlay: 1.210s
#   - Crop result: 0.439s
#   - Update match region: 0.004s
# [Total for image 55: 15.226s]
#
# Processing image 56/100
# Adjusted scaling factor from 0.9771 to 1.0
#   - Find matches: 12.615s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.027s
#     - SIFT detection: 10.197s
#     - FLANN matching: 1.795s
#     - Filter matches: 0.013s
#     - Extract points: 0.162s
#   - Align images: 0.155s
#   - Warp and overlay: 1.093s
#   - Crop result: 0.389s
#   - Update match region: 0.005s
# [Total for image 56: 14.258s]
#
# Processing image 57/100
# Adjusted scaling factor from 0.9725 to 1.0
#   - Find matches: 13.384s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.023s
#     - SIFT detection: 11.007s
#     - FLANN matching: 1.748s
#     - Filter matches: 0.010s
#     - Extract points: 0.068s
#   - Align images: 0.028s
#   - Warp and overlay: 1.274s
#   - Crop result: 0.465s
#   - Update match region: 0.005s
# [Total for image 57: 15.157s]
#
# Processing image 58/100
# Adjusted scaling factor from 0.9893 to 1.0
#   - Find matches: 13.827s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.030s
#     - SIFT detection: 11.468s
#     - FLANN matching: 1.715s
#     - Filter matches: 0.009s
#     - Extract points: 0.072s
#   - Align images: 0.030s
#   - Warp and overlay: 1.124s
#   - Crop result: 0.434s
#   - Update match region: 0.005s
# [Total for image 58: 15.422s]
#
# Processing image 59/100
# Adjusted scaling factor from 0.9861 to 1.0
#   - Find matches: 13.509s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.018s
#     - SIFT detection: 11.141s
#     - FLANN matching: 1.701s
#     - Filter matches: 0.009s
#     - Extract points: 0.050s
#   - Align images: 0.001s
#   - Warp and overlay: 1.297s
#   - Crop result: 0.490s
#   - Update match region: 0.000s
# [Total for image 59: 15.302s]
#
# Processing image 60/100
# Adjusted scaling factor from 0.9822 to 1.0
#   - Find matches: 14.668s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.023s
#     - SIFT detection: 12.389s
#     - FLANN matching: 1.743s
#     - Filter matches: 0.009s
#     - Extract points: 0.068s
#   - Align images: 0.028s
#   - Warp and overlay: 1.326s
#   - Crop result: 0.476s
#   - Update match region: 0.005s
# [Total for image 60: 16.503s]
#   - Saved result_60.png
#
# Processing image 61/100
# Adjusted scaling factor from 0.9837 to 1.0
#   - Find matches: 14.451s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.033s
#     - SIFT detection: 11.768s
#     - FLANN matching: 1.952s
#     - Filter matches: 0.011s
#     - Extract points: 0.069s
#   - Align images: 0.030s
#   - Warp and overlay: 1.408s
#   - Crop result: 0.537s
#   - Update match region: 0.005s
# [Total for image 61: 16.433s]
#
# Processing image 62/100
# Adjusted scaling factor from 0.9775 to 1.0
#   - Find matches: 15.502s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.066s
#     - Convert to grayscale: 0.053s
#     - SIFT detection: 12.893s
#     - FLANN matching: 1.818s
#     - Filter matches: 0.020s
#     - Extract points: 0.137s
#   - Align images: 0.144s
#   - Warp and overlay: 1.426s
#   - Crop result: 0.529s
#   - Update match region: 0.023s
# [Total for image 62: 17.625s]
#
# Processing image 63/100
# Adjusted scaling factor from 0.9792 to 1.0
#   - Find matches: 18.145s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.001s
#     - Convert to grayscale: 0.046s
#     - SIFT detection: 15.571s
#     - FLANN matching: 1.831s
#     - Filter matches: 0.012s
#     - Extract points: 0.075s
#   - Align images: 0.030s
#   - Warp and overlay: 1.657s
#   - Crop result: 0.594s
#   - Update match region: 0.005s
# [Total for image 63: 20.453s]
#
# Processing image 64/100
# Adjusted scaling factor from 0.9822 to 1.0
#   - Find matches: 13.641s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.148s
#     - SIFT detection: 11.192s
#     - FLANN matching: 1.712s
#     - Filter matches: 0.012s
#     - Extract points: 0.052s
#   - Align images: 0.002s
#   - Warp and overlay: 1.443s
#   - Crop result: 0.557s
#   - Update match region: 0.000s
# [Total for image 64: 15.646s]
#
# Processing image 65/100
# Adjusted scaling factor from 0.9687 to 1.0
#   - Find matches: 16.401s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.031s
#     - SIFT detection: 13.640s
#     - FLANN matching: 2.002s
#     - Filter matches: 0.013s
#     - Extract points: 0.080s
#   - Align images: 0.028s
#   - Warp and overlay: 1.908s
#   - Crop result: 0.701s
#   - Update match region: 0.005s
# [Total for image 65: 19.045s]
#
# Processing image 66/100
# Adjusted scaling factor from 0.9733 to 1.0
#   - Find matches: 26.529s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.177s
#     - SIFT detection: 23.597s
#     - FLANN matching: 2.033s
#     - Filter matches: 0.012s
#     - Extract points: 0.080s
#   - Align images: 0.034s
#   - Warp and overlay: 1.818s
#   - Crop result: 0.594s
#   - Update match region: 0.005s
# [Total for image 66: 28.982s]
#
# Processing image 67/100
# Adjusted scaling factor from 0.9827 to 1.0
#   - Find matches: 18.094s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.001s
#     - Convert to grayscale: 0.199s
#     - SIFT detection: 14.928s
#     - FLANN matching: 1.929s
#     - Filter matches: 0.012s
#     - Extract points: 0.075s
#   - Align images: 0.029s
#   - Warp and overlay: 1.842s
#   - Crop result: 0.812s
#   - Update match region: 0.005s
# [Total for image 67: 20.785s]
#
# Processing image 68/100
# Adjusted scaling factor from 0.9763 to 1.0
#   - Find matches: 16.519s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.149s
#     - SIFT detection: 13.567s
#     - FLANN matching: 1.839s
#     - Filter matches: 0.031s
#     - Extract points: 0.149s
#   - Align images: 0.144s
#   - Warp and overlay: 1.817s
#   - Crop result: 0.793s
#   - Update match region: 0.055s
# [Total for image 68: 19.331s]
#
# Processing image 69/100
# Adjusted scaling factor from 0.9953 to 1.0
#   - Find matches: 17.639s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.002s
#     - Convert to grayscale: 0.092s
#     - SIFT detection: 14.770s
#     - FLANN matching: 1.833s
#     - Filter matches: 0.011s
#     - Extract points: 0.075s
#   - Align images: 0.026s
#   - Warp and overlay: 2.078s
#   - Crop result: 0.732s
#   - Update match region: 0.006s
# [Total for image 69: 20.488s]
#
# Processing image 70/100
# Adjusted scaling factor from 0.9654 to 1.0
#   - Find matches: 24.017s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.032s
#     - SIFT detection: 21.355s
#     - FLANN matching: 1.882s
#     - Filter matches: 0.013s
#     - Extract points: 0.081s
#   - Align images: 0.031s
#   - Warp and overlay: 2.262s
#   - Crop result: 0.742s
#   - Update match region: 0.005s
# [Total for image 70: 27.060s]
#   - Saved result_70.png
#
# Processing image 71/100
# Adjusted scaling factor from 0.9687 to 1.0
#   - Find matches: 17.917s
#     - Extract ROI: 0.000s
#     - Allocate buffers: 0.000s
#     - Convert to grayscale: 0.163s
#     - SIFT detection: 14.900s
#     - FLANN matching: 1.864s
#     - Filter matches: 0.015s
#     - Extract points: 0.074s
#   - Align images: 0.026s
#   - Warp and overlay: 2.377s
#   - Crop result: 1.010s
#   - Update match region: 0.005s
# [Total for image 71: 21.338s]
#
# Processing image 72/100
# Adjusted scaling factor from 0.9703 to 1.0
